# %%
print ("Hello world")
# Out:
# Hello world

# %% [markdown]
# **Topics**
# 1. Variables, Numbers, Strings
# 2. Lists, Dictionaries, Sets, Tuples
# 3. If condition, for loop
# 4. Functions, Lambda Functions
# 5. Modules (pip install)
# 6. Read, Write files
# 7. Exception handling
# 8. Classes, Objects
# 9. Data structures basics, Big O notation
# 10. Data structures: Arrays, Linked List, Hash Table, Stack, Queue
# 11. Data structures: Tree, Graph
# 12. Algorithms: Binary search, Bubble sort, quick sort, merge sort
# 13. Recursion
# 14. Inheritance, Generators, Iterators
# 15. List Comprehensions, Decorators
# 16. Multithreading, Multiprocessing

# %% [markdown]
# # VARIABLES

# %%
rent = 1220
gas = 202.5
groceries = 305.6
print(rent)
# Out:
# 1220

# %%
total=rent+gas+groceries
print(total)
# Out:
# 1728.1

# %% [markdown]
# # NUMBERS

# %%
12+34
# Out:
# 46

# %%
3-4
# Out:
# -1

# %%
3/4
# Out:
# 0.75

# %%
3//4
# Out:
# 0

# %%
3%4
# Out:
# 3

# %%
11%2
# Out:
# 1

# %%
2**4
# Out:
# 16

# %%
round(3.1415986, 2)
# Out:
# 3.14

# %%
6-5.7
# Out:
# 0.2999999999999998

# %% [markdown]
# # STRINGS

# %%
text="ice cream"
text
# Out:
# 'ice cream'

# %%
text[1]
# Out:
# 'c'

# %%
text[0:3]
# Out:
# 'ice'

# %%
text[4:]
# Out:
# 'cream'

# %%
text[:3]
# Out:
# 'ice'

# %%
text = "let's learn python"
text
# Out:
# "let's learn python"

# %%
adress = '''purple street
new york
usa'''
adress
# Out:
# 'purple street\nnew york\nusa'

# %% [markdown]
# # LIST

# %%
courses = ['history', 'math', 'physics', 'comsci']
print(courses)
# Out:
# ['history', 'math', 'physics', 'comsci']

# %%
print(len(courses))
# Out:
# 4

# %%
print(courses[2])
# Out:
# physics

# %%
print(courses[-1])
# Out:
# comsci

# %%
print(courses[:2])
# Out:
# ['history', 'math']

# %%
print(courses[1:])
# Out:
# ['math', 'physics', 'comsci']

# %%
courses.append('Art')

# %%
courses
# Out:
# ['history', 'math', 'physics', 'comsci', 'Art']

# %%
courses.insert(1, 'cse')

# %%
courses
# Out:
# ['history', 'cse', 'math', 'physics', 'comsci', 'Art']

# %%
course_2 = ['education', 'dsa']
courses.extend(course_2)

# %%
courses
# Out:
# ['history', 'cse', 'math', 'physics', 'comsci', 'Art', 'education', 'dsa']
